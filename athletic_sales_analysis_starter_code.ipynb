# %%
# Import Libraries and Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
raw_df1 = pd.read_csv("Resources/athletic_sales_2020.csv")
raw_df2 = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
raw_df1
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
raw_df2
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
raw_df1.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
raw_df2.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_df = pd.concat([raw_df1, raw_df2]).reset_index(drop=True)

# %%
# Check if any values are null.
if combined_df.isnull().values.any():
    print("There are null values in the DataFrame.")
else:
    print("There are no null values in the DataFrame.")
# Out:
# There are no null values in the DataFrame.

# %%
# Check the data type of each column
combined_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
# combined_df['invoice_date'] = pd.to_datetime(combined_df['invoice_date'], format='%d-%m-%Y')
combined_df['invoice_date'] = pd.to_datetime(combined_df['invoice_date'])
# Out:
# C:\Users\phessou\AppData\Local\Temp\ipykernel_24916\3705872246.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_df['invoice_date'] = pd.to_datetime(combined_df['invoice_date'])

# %%
# Confirm that the "invoice_date" data type has been changed.
combined_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 1     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3     Foot Locker      1185732   2020-01-01  Northeast      New York
# 4     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9639  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9640       Amazon      1185732   2021-12-31  Northeast         Maine
# 9641       Amazon      1185732   2021-12-31  Northeast         Maine
# 9642  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
Total_Products_Sold = combined_df.groupby(['region', 'state', 'city'])

# Show the top 5 results.
Total_Products_Sold.head(5)
# Out:
#            retailer  retailer_id invoice_date     region         state  \
# 0       Foot Locker      1185732       1/1/20  Northeast      New York
# 1       Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2       Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3       Foot Locker      1185732       1/1/20  Northeast      New York
# 4       Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...             ...          ...          ...        ...           ...
# 6476  Sports Direct      1197831      8/15/21      South         Texas
# 6477  Sports Direct      1197831      8/15/21      South         Texas
# 6480  Sports Direct      1197831      8/15/21      South         Texas
# 6483  Sports Direct      1197831      8/16/21      South         Texas
# 6495  Sports Direct      1197831      8/16/21      South         Texas
#
#               city                product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pd.pivot_table(combined_df, values='units_sold', index=['retailer', 'retailer_id'], columns=['region', 'state', 'city'], aggfunc=np.sum)

# Rename the "units_sold" column to "Total_Products_Sold"
renamed_colum = combined_df.rename(columns={'units_sold': 'Total_Products_Sold'})

# Show the top 5 results.
renamed_colum.head(5)
# Out:
# C:\Users\phessou\AppData\Local\Temp\ipykernel_24916\2869231190.py:2: FutureWarning: The provided callable <function sum at 0x000001FE3263A950> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(combined_df, values='units_sold', index=['retailer', 'retailer_id'], columns=['region', 'state', 'city'], aggfunc=np.sum)
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  Total_Products_Sold  \
# ...

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
total_sales_by_region = combined_df.groupby(['region', 'state', 'city'])['total_sales'].sum()


# Rename the "total_sales" column to "Total Sales"
renamed_total_sales = combined_df.rename(columns={'total_sales': 'Total Sales'})


# Show the top 5 results.
renamed_total_sales.head(5)
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732   2020-01-01  Northeast      New York
# 1  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3  Foot Locker      1185732   2020-01-01  Northeast      New York
# 4  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    Total Sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pd.pivot_table(combined_df, values='total_sales', index=['retailer', 'retailer_id'], columns=['region', 'state', 'city'], aggfunc=np.sum)

# Optional: Rename the "total_sales" column to "Total Sales"
renamed_total_sales = combined_df.rename(columns={'total_sales': 'Total Sales'})

# Show the top 5 results.
renamed_total_sales.head(5)
# Out:
# C:\Users\phessou\AppData\Local\Temp\ipykernel_24916\2488572579.py:2: FutureWarning: The provided callable <function sum at 0x000001FE3263A950> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(combined_df, values='total_sales', index=['retailer', 'retailer_id'], columns=['region', 'state', 'city'], aggfunc=np.sum)
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732   2020-01-01  Northeast      New York
# 1  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3  Foot Locker      1185732   2020-01-01  Northeast      New York
# 4  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
Total_Products_Sold = combined_df.groupby(['region', 'state', 'city'])
renamed_total_sales = combined_df.rename(columns={'total_sales': 'Total Sales'})
# Show the top 5 results.
renamed_total_sales.head(5)
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    Total Sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
total_sales = pd.pivot_table(combined_df, values='total_sales', index=['retailer'], columns=['region', 'state', 'city'], aggfunc=np.sum)

# Optional: Rename the "total_sales" column to "Total Sales"
renamed_total_sales = combined_df.rename(columns={'total_sales': 'Total Sales'})

# Show the top 5 results.
renamed_total_sales.head(20)
# Out:
# C:\Users\phessou\AppData\Local\Temp\ipykernel_24916\3287588454.py:2: FutureWarning: The provided callable <function sum at 0x000001FE3263A950> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_sales = pd.pivot_table(combined_df, values='total_sales', index=['retailer'], columns=['region', 'state', 'city'], aggfunc=np.sum)
#        retailer  retailer_id invoice_date     region         state  \
# 0   Foot Locker      1185732       1/1/20  Northeast      New York
# 1   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3   Foot Locker      1185732       1/1/20  Northeast      New York
# 4   Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 5   Foot Locker      1185732       1/1/20  Northeast      New York
# ...

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
# women_athletic_footwear_sales_data = pd.pivot_table(combined_df, values='total_sales', index=['retailer'], columns=['region', 'state', 'city'], aggfunc=np.sum)
women_atheletic_footwear_sales_data = combined_df[combined_df["product"] == "Women's Athletic Footwear"]
women_atheletic_footwear_sales_data.head()
# Out:
#        retailer  retailer_id invoice_date     region         state  \
# 21  Foot Locker      1185732       1/4/20  Northeast      New York
# 22  Foot Locker      1185732       1/4/20  Northeast      New York
# 23  Foot Locker      1185732       1/4/20  Northeast      New York
# 26    West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27    West Gear      1128299       1/5/20  Northeast  Pennsylvania
#
#             city                    product  price_per_unit  units_sold  \
# 21      New York  Women's Athletic Footwear              36         281
# 22      New York  Women's Athletic Footwear              41         247
# 23      New York  Women's Athletic Footwear              45         850
# 26  Philadelphia  Women's Athletic Footwear              45         300
# 27  Philadelphia  Women's Athletic Footwear              34          90
#
#     total_sales  operating_profit sales_method
# 21        10116           3742.92       Outlet
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
women_atheletic_footwear_sales = combined_df[combined_df["product"] == "Women's Athletic Footwear"]

# Group by "retailer", "region", "state", and "city" columns and sum the total sales
grouped_sales = women_atheletic_footwear_sales.groupby(["retailer", "region", "state", "city"])["total_sales"].sum()
# women_atheletic_footwear_sales_data_per_rsc  = pd.pivot_table(combined_df, values='total_sales', index=['retailer'], columns=['region', 'state', 'city'], aggfunc=np.sum)
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
renamed_units_sold = combined_df.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})
# Show the top 5 results.
renamed_units_sold.head(5)
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732   2020-01-01  Northeast      New York
# 1  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3  Foot Locker      1185732   2020-01-01  Northeast      New York
# 4  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
#
#            city                product  price_per_unit  \
# 0      New York  Men's Street Footwear              50
# 1  Philadelphia        Women's Apparel              68
# 2  Philadelphia        Women's Apparel              75
# 3      New York  Men's Street Footwear              34
# 4  Philadelphia        Women's Apparel              53
#
#    Womens_Footwear_Units_Sold  total_sales  operating_profit sales_method
# 0                        1200       600000         300000.00     In-store
# 1                          83         5644           2426.92       Online
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Group by "retailer", "region", "state", and "city" columns and aggregate the total sales
# women_footwear_sales_summary = women_atheletic_footwear_sales_data.groupby(["region", "state", "city"]).size().reset_index(name="total_sales")
pivot_table = women_atheletic_footwear_sales.pivot_table(index=["retailer", "region", "state", "city"], values="total_sales", aggfunc="sum")

# Sort the results in descending order based on total sales
# women_footwear_sales_summary = women_footwear_sales_summary.sort_values(by="total_sales", ascending=False)

# Display the DataFrame with total sales for each combination of retailer, region, state, and city
# print(women_footwear_sales_summary)

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
renamed_units_sold = combined_df.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})
# Show the top 5 results.
pivot_table.head(5)
# Out:
#                                              total_sales
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus        1885400
#          Northeast Maine         Portland         697119
#                    Massachusetts Boston           405484
#                    New Hampshire Manchester      1070231
#                    Vermont       Burlington      1447437

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_table = pd.pivot_table(combined_df, index='invoice_date', values='total_sales')


# Optional: Rename the "total_sales" column to "Total Sales"
renamed_total_sales = combined_df.rename(columns={'total_sales': 'Total Sales'})
# Show the table.
pivot_table.head()
renamed_total_sales.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732   2020-01-01  Northeast      New York
# 1  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3  Foot Locker      1185732   2020-01-01  Northeast      New York
# 4  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    Total Sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
resampled_daily = pivot_table.resample('D').sum()
# Sort the resampled pivot table in ascending order on "Total Sales".
sorted_resampled_daily = resampled_daily.sort_values(by='total_sales', ascending=True)

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
resampled_weekly = pivot_table.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
sorted_resampled_weekly = resampled_weekly.sort_values(by='total_sales', ascending=True)

# %%
C:\Users\phessou\Columbia_AIBootCamp\Week5\Module5_Challenge\M5_Starter_Code\athletic_sales_analysis_starter_code.ipynb
